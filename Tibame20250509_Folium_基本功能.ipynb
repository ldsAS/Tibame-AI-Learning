# %% [markdown]
# <a href="https://colab.research.google.com/github/ldsAS/Tibame-AI-Learning/blob/main/Tibame20250509_Folium_%E5%9F%BA%E6%9C%AC%E5%8A%9F%E8%83%BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Folium 簡介
# Folium 是一個用於 Python 的開源地圖可視化庫，基於 Leaflet.js，可以輕鬆地在 Jupyter Notebook 或 Python 腳本中創建互動式地圖。
# - https://python-visualization.github.io/folium
# - https://python-visualization.github.io/folium/latest/getting_started.html
# - https://python-visualization.github.io/folium/latest/user_guide.html

# %%
# 安裝
! pip install folium

# %% [markdown]
# # 創建地圖 Creating a map

# %%
# 以下是創建地圖的基本範例：
import folium

# 設定地圖的中心點 (台北市)
m = folium.Map(location=[25.0330, 121.5654], zoom_start=12)
# 加入標記點
folium.Marker([25.0330, 121.5654], popup="台北101", tooltip="點我！").add_to(m)
# 顯示地圖
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da06cfc60bac21b3c245884d3b3386a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da06cfc60bac21b3c245884d3b3386a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da06cfc60bac21b3c245884d3b3386a6 = L.map(
#                 &quot;map_da06cfc60bac21b3c245884d3b3386a6&quot;,
#                 {
#                     center: [25.033, 121.5654],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2382f6cb47c4bc1dfaed88db2cf8d5b5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2382f6cb47c4bc1dfaed88db2cf8d5b5.addTo(map_da06cfc60bac21b3c245884d3b3386a6);
#
#
#             var marker_ecc2867b83eb63ac0c4f652b65cfc321 = L.marker(
#                 [25.033, 121.5654],
#                 {
# }
#             ).addTo(map_da06cfc60bac21b3c245884d3b3386a6);
#
#
#         var popup_0146a2074a8f8906469b5171714ea8db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be12cbf0bbee8c2324b6589d32e1b30e = $(`&lt;div id=&quot;html_be12cbf0bbee8c2324b6589d32e1b30e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;台北101&lt;/div&gt;`)[0];
#                 popup_0146a2074a8f8906469b5171714ea8db.setContent(html_be12cbf0bbee8c2324b6589d32e1b30e);
#
#
#
#         marker_ecc2867b83eb63ac0c4f652b65cfc321.bindPopup(popup_0146a2074a8f8906469b5171714ea8db)
#         ;
#
#
#
#
#             marker_ecc2867b83eb63ac0c4f652b65cfc321.bindTooltip(
#                 `&lt;div&gt;
#                      點我！
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 將其儲存為 HTML 檔案：
m.save("C:/DATA/TEST.html")

# %%
# 使用不同的底圖
''' 選項
"OpenStreetMap", "CartoDB positron", "CartoDB dark_matter"
"Esri WorldImagery", "Esri WorldStreetMap", "Esri NatGeoWorldMap", "Esri OceanBasemap", "Esri WorldGrayCanvas"
'''
import folium
# folium.Map([25.0330, 121.5654], tiles="cartodb positron")
folium.Map([25.0330, 121.5654], tiles="Esri WorldStreetMap")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4fa74634543ffc76f38f68ae5e5dbc95 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4fa74634543ffc76f38f68ae5e5dbc95&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4fa74634543ffc76f38f68ae5e5dbc95 = L.map(
#                 &quot;map_4fa74634543ffc76f38f68ae5e5dbc95&quot;,
#                 {
#                     center: [25.033, 121.5654],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6274ede5555441d854074e00f0850e35 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Street_Map/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, DeLorme, NAVTEQ, USGS, Intermap, iPC, NRCAN, Esri Japan, METI, Esri China (Hong Kong), Esri (Thailand), TomTom, 2012&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6274ede5555441d854074e00f0850e35.addTo(map_4fa74634543ffc76f38f68ae5e5dbc95);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 添加標記 Adding markers
# - https://python-visualization.github.io/folium/latest/reference.html#folium.map.Marker
# - https://python-visualization.github.io/folium/latest/reference.html#folium.map.Icon
#     - https://fontawesome.com/v4/icons/

# %%
import folium
m = folium.Map([25.0330, 121.5654], zoom_start=12)

folium.Marker([25.0330, 121.5654], tooltip="台北101", popup="全台灣最高的大樓", icon=folium.Icon(icon="cloud"),).add_to(m)

folium.Marker(location=[25.0400306,121.5541203],tooltip="國父紀念館",popup="1972 年建的多用途建築",icon=folium.Icon(color="green")).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f7e512c3245335ddf594f135051fd52 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f7e512c3245335ddf594f135051fd52&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f7e512c3245335ddf594f135051fd52 = L.map(
#                 &quot;map_1f7e512c3245335ddf594f135051fd52&quot;,
#                 {
#                     center: [25.033, 121.5654],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d7d639e109270b3064b7b327e38cc6d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3d7d639e109270b3064b7b327e38cc6d.addTo(map_1f7e512c3245335ddf594f135051fd52);
#
#
#             var marker_f34587132c5d17eeacc6eaf081c2e2f0 = L.marker(
#                 [25.033, 121.5654],
#                 {
# }
#             ).addTo(map_1f7e512c3245335ddf594f135051fd52);
#
#
#             var icon_9f76d1f10d4789bd6f0213d9251076c0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e6989ddbe451e1f556b64faa7090c222 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e4a8ec1eda1f9391263643206708c2b = $(`&lt;div id=&quot;html_9e4a8ec1eda1f9391263643206708c2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;全台灣最高的大樓&lt;/div&gt;`)[0];
#                 popup_e6989ddbe451e1f556b64faa7090c222.setContent(html_9e4a8ec1eda1f9391263643206708c2b);
#
#
#
#         marker_f34587132c5d17eeacc6eaf081c2e2f0.bindPopup(popup_e6989ddbe451e1f556b64faa7090c222)
#         ;
#
#
#
#
#             marker_f34587132c5d17eeacc6eaf081c2e2f0.bindTooltip(
#                 `&lt;div&gt;
#                      台北101
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_f34587132c5d17eeacc6eaf081c2e2f0.setIcon(icon_9f76d1f10d4789bd6f0213d9251076c0);
#
#
#             var marker_1c8e2966af717c9dd66b9517b51dd92f = L.marker(
#                 [25.0400306, 121.5541203],
#                 {
# }
#             ).addTo(map_1f7e512c3245335ddf594f135051fd52);
#
#
#             var icon_906932681528e0868542b198f8d9cabb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0b5797acc3814f8ec1a6a0cb12053680 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c27e15b0c9b12b6c72626b649865d148 = $(`&lt;div id=&quot;html_c27e15b0c9b12b6c72626b649865d148&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1972 年建的多用途建築&lt;/div&gt;`)[0];
#                 popup_0b5797acc3814f8ec1a6a0cb12053680.setContent(html_c27e15b0c9b12b6c72626b649865d148);
#
#
#
#         marker_1c8e2966af717c9dd66b9517b51dd92f.bindPopup(popup_0b5797acc3814f8ec1a6a0cb12053680)
#         ;
#
#
#
#
#             marker_1c8e2966af717c9dd66b9517b51dd92f.bindTooltip(
#                 `&lt;div&gt;
#                      國父紀念館
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_1c8e2966af717c9dd66b9517b51dd92f.setIcon(icon_906932681528e0868542b198f8d9cabb);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 使用HTML格式當作popup
import folium

html = """
<h1>台北101</h1><br>
<p>
    位於臺灣臺北市信義區的超高層摩天大樓，作為主體建築的塔樓高
    <span style="color:red;">508</span> 公尺，地上101層、地下5層，附設的裙樓則為購物中心「TAIPEI 101 MALL」。
</p>
<p>
    <a href="https://zh.wikipedia.org/zh-tw/%E5%8F%B0%E5%8C%97101" target="_blank">查看維基百科</a>
</p>
"""


# 設定地圖的中心點 (台北市)
m = folium.Map(location=[25.0330, 121.5654], zoom_start=12)
# 加入標記點
folium.Marker([25.0330, 121.5654], popup=folium.Popup(html, max_width=300), tooltip="台北101").add_to(m)
# 顯示地圖
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58afa301f81bdde171d9ad6b572615bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58afa301f81bdde171d9ad6b572615bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58afa301f81bdde171d9ad6b572615bf = L.map(
#                 &quot;map_58afa301f81bdde171d9ad6b572615bf&quot;,
#                 {
#                     center: [25.033, 121.5654],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4654d1d2d5bef8d61f2f2afc6f8ab3e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4654d1d2d5bef8d61f2f2afc6f8ab3e1.addTo(map_58afa301f81bdde171d9ad6b572615bf);
#
#
#             var marker_d49a22ef8db416bc9fcc2a5219067812 = L.marker(
#                 [25.033, 121.5654],
#                 {
# }
#             ).addTo(map_58afa301f81bdde171d9ad6b572615bf);
#
#
#         var popup_3b0c55828c188db298bf70f48f2ad749 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_c528a9f5774b0638eeba97161a25a5f0 = $(`&lt;div id=&quot;html_c528a9f5774b0638eeba97161a25a5f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; &lt;h1&gt;台北101&lt;/h1&gt;&lt;br&gt; &lt;p&gt;     位於臺灣臺北市信義區的超高層摩天大樓，作為主體建築的塔樓高     &lt;span style=&quot;color:red;&quot;&gt;508&lt;/span&gt; 公尺，地上101層、地下5層，附設的裙樓則為購物中心「TAIPEI 101 MALL」。 &lt;/p&gt; &lt;p&gt;     &lt;a href=&quot;https://zh.wikipedia.org/zh-tw/%E5%8F%B0%E5%8C%97101&quot; target=&quot;_blank&quot;&gt;查看維基百科&lt;/a&gt; &lt;/p&gt; &lt;/div&gt;`)[0];
#                 popup_3b0c55828c188db298bf70f48f2ad749.setContent(html_c528a9f5774b0638eeba97161a25a5f0);
#
#
#
#         marker_d49a22ef8db416bc9fcc2a5219067812.bindPopup(popup_3b0c55828c188db298bf70f48f2ad749)
#         ;
#
#
#
#
#             marker_d49a22ef8db416bc9fcc2a5219067812.bindTooltip(
#                 `&lt;div&gt;
#                      台北101
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 使用內嵌網頁當作popup
import folium

m = folium.Map(location=[25.0330, 121.5654], zoom_start=12)

folium.Marker(
    [25.0330, 121.5654],
    popup=folium.Popup(iframe, max_width=500),
    tooltip="點擊查看台北101資訊"
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_009a90540675cf39e81be94de6a15adf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_009a90540675cf39e81be94de6a15adf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_009a90540675cf39e81be94de6a15adf = L.map(
#                 &quot;map_009a90540675cf39e81be94de6a15adf&quot;,
#                 {
#                     center: [25.033, 121.5654],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05d19f977a6a0cf0a05daa08979018ba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_05d19f977a6a0cf0a05daa08979018ba.addTo(map_009a90540675cf39e81be94de6a15adf);
#
#
#             var marker_77f045b79a2a7ec7389cecdf1c1ea6ab = L.marker(
#                 [25.033, 121.5654],
#                 {
# }
#             ).addTo(map_009a90540675cf39e81be94de6a15adf);
#
#
#         var popup_0363e4a8712fecd454e26ed4e43a3a92 = L.popup({
#   &quot;maxWidth&quot;: 500,
# });
#
#
#
#                 var i_frame_c2de9626cc20f153a0c889d6df0b46d3 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8aWZyYW1lIHNyYz0iaHR0cHM6Ly96aC53aWtpcGVkaWEub3JnL3poLXR3LyVFNSU4RiVCMCVFNSU4QyU5NzEwMSIgd2lkdGg9IjUwMCIgaGVpZ2h0PSIzMDAiPjwvaWZyYW1lPg==&quot; width=&quot;520&quot; style=&quot;border:none !important;&quot; height=&quot;320&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_0363e4a8712fecd454e26ed4e43a3a92.setContent(i_frame_c2de9626cc20f153a0c889d6df0b46d3);
#
#
#
#         marker_77f045b79a2a7ec7389cecdf1c1ea6ab.bindPopup(popup_0363e4a8712fecd454e26ed4e43a3a92)
#         ;
#
#
#
#
#             marker_77f045b79a2a7ec7389cecdf1c1ea6ab.bindTooltip(
#                 `&lt;div&gt;
#                      點擊查看台北101資訊
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 在地圖上畫幾何圖形

# %%
# Line
# Coordinates are 15 points on the great circle from Boston to San Francisco.
coordinates = [
    [42.3581, -71.0636],
    [42.82995815, -74.78991444],
    [43.17929819, -78.56603306],
    [43.40320216, -82.37774519],
    [43.49975489, -86.20965845],
    [43.46811941, -90.04569087],
    [43.30857071, -93.86961818],
    [43.02248456, -97.66563267],
    [42.61228259, -101.41886832],
    [42.08133868, -105.11585198],
    [41.4338549, -108.74485069],
    [40.67471747, -112.29609954],
    [39.8093434, -115.76190821],
    [38.84352776, -119.13665678],
    [37.7833, -122.4167],
]

# Create the map and add the line
m = folium.Map(location=[41.9, -97.3], zoom_start=4)

folium.PolyLine(
    locations=coordinates,
    color="#FF0000",
    weight=5,
    tooltip="From Boston to San Francisco",
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e5e1938a1e207985ae858f819e6e997 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e5e1938a1e207985ae858f819e6e997&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e5e1938a1e207985ae858f819e6e997 = L.map(
#                 &quot;map_4e5e1938a1e207985ae858f819e6e997&quot;,
#                 {
#                     center: [41.9, -97.3],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba1326970b8cdde0ce065e3ea376c2e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ba1326970b8cdde0ce065e3ea376c2e1.addTo(map_4e5e1938a1e207985ae858f819e6e997);
#
#
#             var poly_line_1ac53dffbb7315dfba83be85477fcc94 = L.polyline(
#                 [[42.3581, -71.0636], [42.82995815, -74.78991444], [43.17929819, -78.56603306], [43.40320216, -82.37774519], [43.49975489, -86.20965845], [43.46811941, -90.04569087], [43.30857071, -93.86961818], [43.02248456, -97.66563267], [42.61228259, -101.41886832], [42.08133868, -105.11585198], [41.4338549, -108.74485069], [40.67471747, -112.29609954], [39.8093434, -115.76190821], [38.84352776, -119.13665678], [37.7833, -122.4167]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_4e5e1938a1e207985ae858f819e6e997);
#
#
#             poly_line_1ac53dffbb7315dfba83be85477fcc94.bindTooltip(
#                 `&lt;div&gt;
#                      From Boston to San Francisco
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Circle 使用像素當作單位
import folium
m = folium.Map(location=[25.0330, 121.5654], zoom_start=12)
folium.Marker([25.0330, 121.5654], popup="台北101", tooltip="點我！").add_to(m)
folium.CircleMarker(
    location=[25.0330, 121.5654], #中心點
    radius=50,
    color="cornflowerblue", #顏色
    stroke=True, #是否顯示邊框
    fill=True, #是否要用色彩填滿圓形區域
    fill_opacity=0.6, #圓形色彩的透明度
    opacity=1, #邊框的透明度
    popup="這是一個圓形",
    tooltip="使用像素當作單位",
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_656408a0897bc88dd15870787ef53270 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_656408a0897bc88dd15870787ef53270&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_656408a0897bc88dd15870787ef53270 = L.map(
#                 &quot;map_656408a0897bc88dd15870787ef53270&quot;,
#                 {
#                     center: [25.033, 121.5654],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b16198a779bfb1a209b83857fac77534 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b16198a779bfb1a209b83857fac77534.addTo(map_656408a0897bc88dd15870787ef53270);
#
#
#             var marker_e1644019cd56538b460f5ee3e05c967d = L.marker(
#                 [25.033, 121.5654],
#                 {
# }
#             ).addTo(map_656408a0897bc88dd15870787ef53270);
#
#
#         var popup_43369a48db2272f233a498a4a9384f50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff9aa8772ee2debd5fc3ab4a47540705 = $(`&lt;div id=&quot;html_ff9aa8772ee2debd5fc3ab4a47540705&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;台北101&lt;/div&gt;`)[0];
#                 popup_43369a48db2272f233a498a4a9384f50.setContent(html_ff9aa8772ee2debd5fc3ab4a47540705);
#
#
#
#         marker_e1644019cd56538b460f5ee3e05c967d.bindPopup(popup_43369a48db2272f233a498a4a9384f50)
#         ;
#
#
#
#
#             marker_e1644019cd56538b460f5ee3e05c967d.bindTooltip(
#                 `&lt;div&gt;
#                      點我！
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_c30435463d96e221de629a221b2fd27c = L.circleMarker(
#                 [25.033, 121.5654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cornflowerblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cornflowerblue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_656408a0897bc88dd15870787ef53270);
#
#
#         var popup_33b84945866e0b8efe04a3134e906a97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e9d459e2cf0eec37194cd42bb7191de = $(`&lt;div id=&quot;html_1e9d459e2cf0eec37194cd42bb7191de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;這是一個圓形&lt;/div&gt;`)[0];
#                 popup_33b84945866e0b8efe04a3134e906a97.setContent(html_1e9d459e2cf0eec37194cd42bb7191de);
#
#
#
#         circle_marker_c30435463d96e221de629a221b2fd27c.bindPopup(popup_33b84945866e0b8efe04a3134e906a97)
#         ;
#
#
#
#
#             circle_marker_c30435463d96e221de629a221b2fd27c.bindTooltip(
#                 `&lt;div&gt;
#                      I am in pixels
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Circle 使用公尺為單位
import folium
m = folium.Map(location=[25.0330, 121.5654], zoom_start=12)
folium.Marker([25.0330, 121.5654], popup="台北101", tooltip="點我！").add_to(m)
folium.Circle(
    location=[25.0330, 121.5654], #中心點
    radius=500,
    color="cornflowerblue", #顏色
    stroke=True, #是否顯示邊框
    fill=True, #是否要用色彩填滿圓形區域
    fill_opacity=0.6, #圓形色彩的透明度
    opacity=1, #邊框的透明度
    popup="這是一個圓形",
    tooltip="使用公尺當作單位",
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2d7b453bfcebabf7623ffa81226d35b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2d7b453bfcebabf7623ffa81226d35b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2d7b453bfcebabf7623ffa81226d35b = L.map(
#                 &quot;map_f2d7b453bfcebabf7623ffa81226d35b&quot;,
#                 {
#                     center: [25.033, 121.5654],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b049d0955ae59494800b0c9a96bc7ec3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b049d0955ae59494800b0c9a96bc7ec3.addTo(map_f2d7b453bfcebabf7623ffa81226d35b);
#
#
#             var marker_9ca3bc5f9cb1cfcb3a8dd05fca909da3 = L.marker(
#                 [25.033, 121.5654],
#                 {
# }
#             ).addTo(map_f2d7b453bfcebabf7623ffa81226d35b);
#
#
#         var popup_11e41e2c9529016d7d51f6b513c85100 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa9ee493e69a38c28b896d848d51fb37 = $(`&lt;div id=&quot;html_fa9ee493e69a38c28b896d848d51fb37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;台北101&lt;/div&gt;`)[0];
#                 popup_11e41e2c9529016d7d51f6b513c85100.setContent(html_fa9ee493e69a38c28b896d848d51fb37);
#
#
#
#         marker_9ca3bc5f9cb1cfcb3a8dd05fca909da3.bindPopup(popup_11e41e2c9529016d7d51f6b513c85100)
#         ;
#
#
#
#
#             marker_9ca3bc5f9cb1cfcb3a8dd05fca909da3.bindTooltip(
#                 `&lt;div&gt;
#                      點我！
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_54fa52949e356b9c7877e020c4b12f34 = L.circle(
#                 [25.033, 121.5654],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cornflowerblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;cornflowerblue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1, &quot;radius&quot;: 500, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f2d7b453bfcebabf7623ffa81226d35b);
#
#
#         var popup_9899b4a0c9646303e8a4bdb74a6e0a69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9358b833271ec3ecc3d8926f94ee3838 = $(`&lt;div id=&quot;html_9358b833271ec3ecc3d8926f94ee3838&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;這是一個圓形&lt;/div&gt;`)[0];
#                 popup_9899b4a0c9646303e8a4bdb74a6e0a69.setContent(html_9358b833271ec3ecc3d8926f94ee3838);
#
#
#
#         circle_54fa52949e356b9c7877e020c4b12f34.bindPopup(popup_9899b4a0c9646303e8a4bdb74a6e0a69)
#         ;
#
#
#
#
#             circle_54fa52949e356b9c7877e020c4b12f34.bindTooltip(
#                 `&lt;div&gt;
#                      使用像素當作單位
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 矩形
m = folium.Map(location=[25.0330, 121.5554], zoom_start=15)

kw = {
    "color": "blue",
    "line_cap": "round",
    "fill": True,
    "fill_color": "red",
    "weight": 5,
    "popup": "台北",
    "tooltip": "<strong>Click me!</strong>",
}

folium.Rectangle(
    bounds=[[25.0330, 121.5654], [25.0430, 121.5754]],
    line_join="round",
    dash_array="5, 5",
    **kw,
).add_to(m)

dx = 0.012
folium.Rectangle(
    bounds=[[25.0330, 121.5654 - dx], [25.0430, 121.5754 - dx]],
    line_join="mitter",
    dash_array="5, 10",
    **kw,
).add_to(m)

folium.Rectangle(
    bounds=[[25.0330, 121.5654 - 2 * dx], [25.0430, 121.5754 - 2 * dx]],
    line_join="bevel",
    dash_array="15, 10, 5, 10, 15",
    **kw,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e249b4c221ab6bb58052761179f4e189 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e249b4c221ab6bb58052761179f4e189&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e249b4c221ab6bb58052761179f4e189 = L.map(
#                 &quot;map_e249b4c221ab6bb58052761179f4e189&quot;,
#                 {
#                     center: [25.033, 121.5554],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21d5ab1cfbe053cb0100ce47069c3b7d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_21d5ab1cfbe053cb0100ce47069c3b7d.addTo(map_e249b4c221ab6bb58052761179f4e189);
#
#
#             var rectangle_945373c1abc2d1603d3a4af1ce3d6a9a = L.rectangle(
#                 [[25.033, 121.5654], [25.043, 121.5754]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_e249b4c221ab6bb58052761179f4e189);
#
#
#         var popup_6f6d8b95735fd9272222aee989bb20bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_320d304f2a1e0318c9b2db712919975d = $(`&lt;div id=&quot;html_320d304f2a1e0318c9b2db712919975d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;台北&lt;/div&gt;`)[0];
#                 popup_6f6d8b95735fd9272222aee989bb20bd.setContent(html_320d304f2a1e0318c9b2db712919975d);
#
#
#
#         rectangle_945373c1abc2d1603d3a4af1ce3d6a9a.bindPopup(popup_6f6d8b95735fd9272222aee989bb20bd)
#         ;
#
#
#
#
#             rectangle_945373c1abc2d1603d3a4af1ce3d6a9a.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click me!&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var rectangle_9cf2f47d1b90aef2cc951c729d1ed50d = L.rectangle(
#                 [[25.033, 121.5534], [25.043, 121.5634]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: &quot;5, 10&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;mitter&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_e249b4c221ab6bb58052761179f4e189);
#
#
#         var popup_3b90306bc982721be977b17dec43ea37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ab36a9c393edb0fa2c2d9b4a82f1d21 = $(`&lt;div id=&quot;html_2ab36a9c393edb0fa2c2d9b4a82f1d21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;台北&lt;/div&gt;`)[0];
#                 popup_3b90306bc982721be977b17dec43ea37.setContent(html_2ab36a9c393edb0fa2c2d9b4a82f1d21);
#
#
#
#         rectangle_9cf2f47d1b90aef2cc951c729d1ed50d.bindPopup(popup_3b90306bc982721be977b17dec43ea37)
#         ;
#
#
#
#
#             rectangle_9cf2f47d1b90aef2cc951c729d1ed50d.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Click me!&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var rectangle_140523e3485c5a8f4393a7899be47c56 = L.rectangle(
#                 [[25.033, 121.5414], [25.043, 121.5514]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: &quot;15, 10, 5, 10, 15&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;bevel&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_e249b4c221ab6bb58052761179f4e189);
#
#
#         var popup_7794318d9c3a0f876a227222e3a5c426 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d950a9860e49a0085dc698dd0376b4db = $(`&lt;div id=&quot;html_d950a9860e49a00

# %%
# Polygon 多邊形
m = folium.Map(location=[35.67, 139.78], zoom_start=13)

locations = [
    [35.6762, 139.7795],
    [35.6718, 139.7831],
    [35.6767, 139.7868],
    [35.6795, 139.7824],
    [35.6787, 139.7791],
]

folium.Polygon(
    locations=locations,
    color="blue",
    weight=6,
    fill_color="red",
    fill_opacity=0.5,
    fill=True,
    popup="Tokyo, Japan",
    tooltip="Click me!",
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad089e586a91ce6b4fc1bba0de02d742 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad089e586a91ce6b4fc1bba0de02d742&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad089e586a91ce6b4fc1bba0de02d742 = L.map(
#                 &quot;map_ad089e586a91ce6b4fc1bba0de02d742&quot;,
#                 {
#                     center: [35.67, 139.78],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28ea38efaa4b9511d0b58e6a3fc0763f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_28ea38efaa4b9511d0b58e6a3fc0763f.addTo(map_ad089e586a91ce6b4fc1bba0de02d742);
#
#
#             var polygon_6bf582f4d1cb68eccf4364d9a784a6da = L.polygon(
#                 [[35.6762, 139.7795], [35.6718, 139.7831], [35.6767, 139.7868], [35.6795, 139.7824], [35.6787, 139.7791]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6}
#             ).addTo(map_ad089e586a91ce6b4fc1bba0de02d742);
#
#
#         var popup_81e93ed924bb280e1a1c726f2d140f85 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8689b019b2234d3f9cef8db520469238 = $(`&lt;div id=&quot;html_8689b019b2234d3f9cef8db520469238&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tokyo, Japan&lt;/div&gt;`)[0];
#                 popup_81e93ed924bb280e1a1c726f2d140f85.setContent(html_8689b019b2234d3f9cef8db520469238);
#
#
#
#         polygon_6bf582f4d1cb68eccf4364d9a784a6da.bindPopup(popup_81e93ed924bb280e1a1c726f2d140f85)
#         ;
#
#
#
#
#             polygon_6bf582f4d1cb68eccf4364d9a784a6da.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# ColorLine
import numpy as np

x = np.linspace(0, 2 * np.pi, 300)

lats = 20 * np.cos(x)
lons = 20 * np.sin(x)
colors = np.sin(5 * x)

import folium

m = folium.Map([0, 0], zoom_start=3)

color_line = folium.ColorLine(
    positions=list(zip(lats, lons)),
    colors=colors,
    colormap=["y", "orange", "r"],
    weight=10,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4656de570a7225ae73d7bbb4954da8ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4656de570a7225ae73d7bbb4954da8ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4656de570a7225ae73d7bbb4954da8ea = L.map(
#                 &quot;map_4656de570a7225ae73d7bbb4954da8ea&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8cc274e1a16d05f07a8b60fab700384a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8cc274e1a16d05f07a8b60fab700384a.addTo(map_4656de570a7225ae73d7bbb4954da8ea);
#
#
#             var color_line_60bea61d8b9f48e873555868495d8272 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var poly_line_8ab008077c64f30e809457fac7d3a313 = L.polyline(
#                 [[[20.0, 0.0], [19.99558428151149, 0.4202490225695083]], [[19.99558428151149, 0.4202490225695083], [19.98233907590294, 0.8403124750011428]], [[16.39976389916292, 11.44760866083885], [16.155600744606296, 11.789680427427898]], [[6.100343541912352, 19.046936989202443], [5.69877383929137, 19.170914864153154]], [[5.69877383929137, 19.170914864153154], [5.294687718569988, 19.286427402783133]], [[-5.899884352444991, 19.109980759482067], [-6.3001292777989555, 18.98179051309492]], [[-16.278580867064825, 11.619285905529262], [-16.519136462777475, 11.274667645839312]], [[-16.519136462777475, 11.274667645839312], [-16.75239767286083, 10.925070810311805]], [[-19.990065090410354, 0.6303155409454055], [-19.998896039909674, 0.21013611037872693]], [[-19.998896039909674, 0.21013611037872693], [-19.998896039909674, -0.21013611037872199]], [[-16.03083710830204, -11.958773415659579], [-15.77601458315871, -12.292980268102752]], [[-6.697592243419727, -18.845218442376407], [-6.300129277798961, -18.98179051309492]], [[-6.300129277798961, -18.98179051309492], [-5.899884352444995, -19.109980759482063]], [[6.499219504556901, -18.914548523070465], [6.89522559482874, -18.773807924776975]], [[15.904303731559574, -12.126546203033254], [16.155600744606293, -11.789680427427902]], [[16.155600744606293, -11.789680427427902], [16.399763899162917, -11.447608660838851]]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff9600ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ff9600ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: null, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(color_line_60bea61d8b9f48e873555868495d8272);
#
#
#             var poly_line_ffcf2c771c4a65b41ac65d94c06c47db = L.polyline(
#                 [[[19.98233907590294, 0.8403124750011428], [19.96027023188427, 1.2600048690995784]], [[19.96027023188427, 1.2600048690995784], [19.929387494435748, 1.6791408805184047]], [[16.866260568222977, 10.748453583879252], [16.636685379653873, 11.100481952528504]], [[16.636685379653873, 11.100481952528504], [16.39976389916292, 11.44760866083885]], [[5.294687718569988, 19.286427402783133], [4.888263612803633, 19.393423598007132]], [[4.888263612803633, 19.393423598007132], [4.479680987436096, 19.491856203317415]], [[-5.091756720497264, 19.340993084618766], [-5.497034204249513, 19.229732576333735]], [[-5.497034204249513, 19.229732576333735], [-5.899884352444991, 19.109980759482067]], [[-16.75239767286083, 10.925070810311805], [-16.978261495731097, 10.570649771067762]], [[-19.97240709091041, 1.0502166419133094], [-19.990065090410354, 0.6303155409454055]], [[-15.77601458315871, -12.292980268102752], [-15.514225814088396, -12.621758886521055]], [[-15.514225814088396, -12.621758886521055], [-15.245586399641862, -12.944964091532086]], [[-7.092097740850718, -18.700324853708295], [-6.697592243419727, -18.845218442376407]], [[6.89522559482874, -18.773807924776975], [7.288186947586425, -18.624777341408162]], [[7.288186947586425, -18.624777341408162], [7.677930042158892, -18.467522580674267]], [[15.380755093854257, -12.78406714402253], [15.645983825709422, -12.458057237211555]], [[15.645983825709422, -12.458057237211555], [15.904303731559574, -12.126546203033254]]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff7800ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ff7800ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;

# %% [markdown]
# # 標示群組 Group

# %%
import folium
m = folium.Map((25.0330, 121.5654), zoom_start=15)

group_1 = folium.FeatureGroup("景點").add_to(m)
folium.Marker([25.0330, 121.5654], tooltip="台北101", popup="全台灣最高的大樓", icon=folium.Icon(color="green"),).add_to(group_1)
folium.Marker(location=[25.0400306,121.5541203],tooltip="國父紀念館",popup="1972 年建的多用途建築",icon=folium.Icon(color="green")).add_to(group_1)


group_2 = folium.FeatureGroup("夜市").add_to(m)
folium.Marker([25.030358, 121.555365], tooltip="通化街夜市", popup="營業至深夜的熱鬧夜市", icon=folium.Icon(icon="cutlery"),).add_to(group_2)


folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2b65cd58e2d5e9e48ec3650c830b274 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2b65cd58e2d5e9e48ec3650c830b274&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2b65cd58e2d5e9e48ec3650c830b274 = L.map(
#                 &quot;map_a2b65cd58e2d5e9e48ec3650c830b274&quot;,
#                 {
#                     center: [25.033, 121.5654],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_309440995cf2cadf1ea8b09a12389943 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_309440995cf2cadf1ea8b09a12389943.addTo(map_a2b65cd58e2d5e9e48ec3650c830b274);
#
#
#             var feature_group_2154e7c1cd9fdf0f836965bc76a7245f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_587fb03e3297be44afdfc1adf54e2514 = L.marker(
#                 [25.033, 121.5654],
#                 {
# }
#             ).addTo(feature_group_2154e7c1cd9fdf0f836965bc76a7245f);
#
#
#             var icon_e61a2fee8f76866c559d6e28c3390fb6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_43a23b6ea71890f47c6619718380699c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a68a2941e9b69c2bcd49b17218766afb = $(`&lt;div id=&quot;html_a68a2941e9b69c2bcd49b17218766afb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;全台灣最高的大樓&lt;/div&gt;`)[0];
#                 popup_43a23b6ea71890f47c6619718380699c.setContent(html_a68a2941e9b69c2bcd49b17218766afb);
#
#
#
#         marker_587fb03e3297be44afdfc1adf54e2514.bindPopup(popup_43a23b6ea71890f47c6619718380699c)
#         ;
#
#
#
#
#             marker_587fb03e3297be44afdfc1adf54e2514.bindTooltip(
#                 `&lt;div&gt;
#                      台北101
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_587fb03e3297be44afdfc1adf54e2514.setIcon(icon_e61a2fee8f76866c559d6e28c3390fb6);
#
#
#             var marker_8423ce2aaa3efb71d5a1592ab0d8b233 = L.marker(
#                 [25.0400306, 121.5541203],
#                 {
# }
#             ).addTo(feature_group_2154e7c1cd9fdf0f836965bc76a7245f);
#
#
#             var icon_2076052c8195938127337f42aaf88194 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_64c6fc283e76b738c798b9bce995a3b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_033917d73bf25cda3bec0f1cc61f24e1 = $(`&lt;div id=&quot;html_033917d73bf25cda3bec0f1cc61f24e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1972 年建的多用途建築&lt;/div&gt;`)[0];
#                 popup_64c6fc283e76b738c798b9bce995a3b1.setContent(html_033917d73bf25cda3bec0f1cc61f24e1);
#
#
#
#         marker_8423ce2aaa3efb71d5a1592ab0d8b233.bindPopup(popup_64c6fc283e76b738c798b9bce995a3b1)
#         ;
#
#
#
#
#             marker_8423ce2aaa3efb71d5a1592ab0d8b233.bindTooltip(
#                 `&lt;div&gt;
#                      國父紀念館
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_8423ce2aaa3efb71d5a1592ab0d8b233.setIcon(icon_2076052c8195938127337f42aaf88194);
#
#
#             feature_group_2154e7c1cd9fdf0f836965bc76a7245f.addTo(map_a2b65cd58e2d5e9e48ec3650c830b274);
#
#
#             var feature_group_b5dde6fa75bb1ff2aa5988ac535c6efd = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_abc882e470934ed7c324282ab7e6955b = L.marker(
#                 [25.030358, 121.555365],
#                 {
# }
#             ).addTo(feature_group_b5dde6fa75bb1ff2aa5988ac535c6efd);
#
#
#             var icon_d82083ec382de8b820cb687006f2774c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cutlery&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d6eacde4c337cfbe7e61cd3f9587e2ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });

# %%
# 子群組
import folium
m = folium.Map((25.0330, 121.5654), zoom_start=15)

fg = folium.FeatureGroup(name="全部")
m.add_child(fg)

group_1 = folium.plugins.FeatureGroupSubGroup(fg, "景點").add_to(m)
folium.Marker([25.0330, 121.5654], tooltip="台北101", popup="全台灣最高的大樓", icon=folium.Icon(color="green"),).add_to(group_1)
folium.Marker(location=[25.0400306,121.5541203],tooltip="國父紀念館",popup="1972 年建的多用途建築",icon=folium.Icon(color="green")).add_to(group_1)


group_2 = folium.plugins.FeatureGroupSubGroup(fg, "夜市").add_to(m)
folium.Marker([25.030358, 121.555365], tooltip="通化街夜市", popup="營業至深夜的熱鬧夜市", icon=folium.Icon(icon="cutlery"),).add_to(group_2)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78b95e34899bf6a9c5ca1281b644f36c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78b95e34899bf6a9c5ca1281b644f36c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78b95e34899bf6a9c5ca1281b644f36c = L.map(
#                 &quot;map_78b95e34899bf6a9c5ca1281b644f36c&quot;,
#                 {
#                     center: [25.033, 121.5654],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7551164e8ed2e6d2255a1dccb4b2e95 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c7551164e8ed2e6d2255a1dccb4b2e95.addTo(map_78b95e34899bf6a9c5ca1281b644f36c);
#
#
#             var feature_group_066abe28f457b65c3c9ac5a2c797ee31 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_066abe28f457b65c3c9ac5a2c797ee31.addTo(map_78b95e34899bf6a9c5ca1281b644f36c);
#
#
#             var feature_group_sub_group_1bc520eca181c38cb7f833e13573bde1 = L.featureGroup.subGroup(
#                 feature_group_066abe28f457b65c3c9ac5a2c797ee31
#             );
#
#
#             var marker_39f1c25c26c64cfb1b1da5e7d94ed653 = L.marker(
#                 [25.033, 121.5654],
#                 {
# }
#             ).addTo(feature_group_sub_group_1bc520eca181c38cb7f833e13573bde1);
#
#
#             var icon_1f4a4a4e564f53741b2209f0faf41c75 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8c2e6b6ce614f4b1ae76eabda421d81c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91cad90a2ead4d8c9d3173f787c45521 = $(`&lt;div id=&quot;html_91cad90a2ead4d8c9d3173f787c45521&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;全台灣最高的大樓&lt;/div&gt;`)[0];
#                 popup_8c2e6b6ce614f4b1ae76eabda421d81c.setContent(html_91cad90a2ead4d8c9d3173f787c45521);
#
#
#
#         marker_39f1c25c26c64cfb1b1da5e7d94ed653.bindPopup(popup_8c2e6b6ce614f4b1ae76eabda421d81c)
#         ;
#
#
#
#
#             marker_39f1c25c26c64cfb1b1da5e7d94ed653.bindTooltip(
#                 `&lt;div&gt;
#                      台北101
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_39f1c25c26c64cfb1b1da5e7d94ed653.setIcon(icon_1f4a4a4e564f53741b2209f0faf41c75);
#
#
#             var marker_97c345660cb8cd07587a0d5673364c40 = L.marker(
#                 [25.0400306, 121.5541203],
#                 {
# }
#             ).addTo(feature_group_sub_group_1bc520eca181c38cb7f833e13573bde1);
#
#
#             var icon_8cc4f5a47cd58ce18312beedcbb10bb0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c666f029d3502fbe67a26350328441e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3faec6a079ff0f5b9e43ddfa86c24213 = $(`&lt;div id=&quot;html_3faec6a079ff0f5b9e43ddfa86c24213&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1972 年建的多用途建築&lt;/div&gt;`)[0];
#                 popup_c666f029d3502fbe67a26350328441e9.setContent(html_3faec6a079ff0f5b9e43ddfa86c24213);
#
#
#
#         marker_97c345660cb8cd07587a0d5673364c40.bindPopup(popup_c666f029d3502fbe67a26350328441e9)
#         ;
#
#
#
#
#             marker_97c345660cb8cd07587a0d5673364c40.bindTooltip(
#                 `&lt;div&gt;
#                      國父紀念館
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_97c345660cb8cd07587a0d5673364c40.setIcon(icon_8cc4f5a47cd58ce18312beedcbb10bb0);
#
#
#             feature_group_sub_group_1bc520eca181c38cb7f833e13573bde1.addTo(map_78b95e34899bf6a9c5ca1281b644f36c);
#
#
#             var feature_group_sub_group_76294e2206b580a92dbe4daec94cf98c = L.featureGroup.subGroup(
#                 feature_group_066abe28f457b65c3c9ac5a2c797ee31
#             );
#
#
#             var marker_e3b4137814a3d17ad6a165a37fcc2f83 = L.marker(
#                 [25.030358, 121.555365],
#                 {
# }
#             ).addTo(feature_group_

# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map((25.0330, 121.5654), zoom_start=15)

marker_cluster_1 = MarkerCluster().add_to(m)
marker_cluster_2 = MarkerCluster().add_to(m)


folium.Marker([25.0330, 121.5654], tooltip="台北101", popup="全台灣最高的大樓", icon=folium.Icon(color="green"),).add_to(marker_cluster_1)
folium.Marker(location=[25.0400306,121.5541203],tooltip="國父紀念館",popup="1972 年建的多用途建築",icon=folium.Icon(color="green")).add_to(marker_cluster_1)

folium.Marker([25.030358, 121.555365], tooltip="通化街夜市", popup="營業至深夜的熱鬧夜市", icon=folium.Icon(icon="cutlery"),).add_to(marker_cluster_2)
folium.Marker([25.0462133,121.5457534], tooltip="遼寧街夜市", popup="小型夜市，設有販售蚵仔煎和燙魷魚等台灣特色料理的攤位。", icon=folium.Icon(icon="cutlery"),).add_to(marker_cluster_2)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4cf0ce3f88dd1275a5da2068031b1525 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4cf0ce3f88dd1275a5da2068031b1525&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4cf0ce3f88dd1275a5da2068031b1525 = L.map(
#                 &quot;map_4cf0ce3f88dd1275a5da2068031b1525&quot;,
#                 {
#                     center: [25.033, 121.5654],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_58a623453f854fe76a99be4b0f65bdc7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_58a623453f854fe76a99be4b0f65bdc7.addTo(map_4cf0ce3f88dd1275a5da2068031b1525);
#
#
#             var marker_cluster_45b8b4cc2dc809767a7eadd8f421df7a = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_ea410047b7f994dc933015dd10f03bcc = L.marker(
#                 [25.033, 121.5654],
#                 {
# }
#             ).addTo(marker_cluster_45b8b4cc2dc809767a7eadd8f421df7a);
#
#
#             var icon_0091ce130be89857802ede432d18038f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_acf869e6bda4610efc69508910b09740 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5f748d55767710678dca6db6117b5c6 = $(`&lt;div id=&quot;html_f5f748d55767710678dca6db6117b5c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;全台灣最高的大樓&lt;/div&gt;`)[0];
#                 popup_acf869e6bda4610efc69508910b09740.setContent(html_f5f748d55767710678dca6db6117b5c6);
#
#
#
#         marker_ea410047b7f994dc933015dd10f03bcc.bindPopup(popup_acf869e6bda4610efc69508910b09740)
#         ;
#
#
#
#
#             marker_ea410047b7f994dc933015dd10f03bcc.bindTooltip(
#                 `&lt;div&gt;
#                      台北101
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_ea410047b7f994dc933015dd10f03bcc.setIcon(icon_0091ce130be89857802ede432d18038f);
#
#
#             var marker_c8be9ce64960f446bcdfe8039de6ab7b = L.marker(
#                 [25.0400306, 121.5541203],
#                 {
# }
#             ).addTo(marker_cluster_45b8b4cc2dc809767a7eadd8f421df7a);
#
#
#             var icon_676ca032920db9c77055e86643cd077e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3ba0576d5862eb2694fcb1473d9044ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ebba21f432fa2fa05f4d73767c5f984 = $(`&lt;div id=&quot;html_8ebba21f432fa2fa05f4d73767c5f984&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1972 年建的多用途建築&lt;/div&gt;`)[0];
#                 popup_3ba0576d5862eb2694fcb1473d9044ab.setContent(html_8ebba21f432fa2fa05f4d73767c5f984);
#
#
#
#         marker_c8be9ce64960f446bcdfe8039de6ab7b.bindPopup(popup_3ba0576d5862eb2694fcb1473d9044ab)
#         ;
#
#
#
#
#             marker_c8be9ce64960f446bcdfe8039de6ab7b.bindTooltip(
#                 `&lt;div&gt;
#                      國父紀念館
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_c8be9ce64960f446bcdfe8039de6ab7b.setIcon(icon_676ca032920db9c77055e86643cd077e);
#
#
#             marker_cluster_45b8b4cc2dc809767a7eadd8f421df7a.addTo(map_4cf0ce3f88dd1275a5da2068031b1525);
#
#
#             var marker_cluster_954dafc006a3faf2bd2154e606318944 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_15e10af12a82cb7337e51372f2085edc = L.marker(
#                 [25.030358, 121.555365],
#                 {
# }
#             ).addTo(marker_cluster_954dafc006a3faf2bd2154e606318944);
#
#
#             var icon_ea53b152f0b8

# %% [markdown]
# # 練習題

# %%
# 練習題
# 在地圖上顯示Youbike的即時訊息
import pandas
import requests
import folium

data_json = requests.get("https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json").json()
data = pd.DataFrame(data_json)
data.head()
# Out:
#          sno                     sna sarea                 mday  \
# 0  500101001      YouBike2.0_捷運科技大樓站   大安區  2025-04-22 09:25:14
# 1  500101002  YouBike2.0_復興南路二段273號前   大安區  2025-04-22 09:11:14
# 2  500101003    YouBike2.0_國北教大實小東側門   大安區  2025-04-22 08:50:02
# 3  500101004       YouBike2.0_和平公園東側   大安區  2025-04-22 09:27:15
# 4  500101005    YouBike2.0_辛亥復興路口西北側   大安區  2025-04-22 08:50:02
#
#               ar     sareaen  \
# 0    復興南路二段235號前  Daan Dist.
# 1   復興南路二段273號西側  Daan Dist.
# 2    和平東路二段96巷7號  Daan Dist.
# 3  和平東路二段118巷33號  Daan Dist.
# 4     復興南路二段368號  Daan Dist.
#
#                                                snaen  \
# 0               YouBike2.0_MRT Technology Bldg. Sta.
# 1           YouBike2.0_No.273， Sec. 2， Fuxing S. Rd.
# 2  YouBike2.0_NTUE Experiment Elementary School (...
# 3                      YouBike2.0_Heping Park (East)
# 4  YouBike2.0_Xinhai Fuxing Rd. Intersection (Nor...
#
#                                     aren act        srcUpdateTime  \
# 0          No.235， Sec. 2， Fuxing S. Rd.   1  2025-04-22 09:28:19
# 1   No.273， Sec. 2， Fuxing S. Rd. (West)   1  2025-04-22 09:28:19
# 2    No. 7， Ln. 96， Sec. 2， Heping E. Rd   1  2025-04-22 09:28:19
# 3  No. 33， Ln. 118， Sec. 2， Heping E. Rd   1  2025-04-22 09:28:19
# 4         No. 368， Sec. 2， Fuxing S. Rd.   1  2025-04-22 09:28:19
#
#             updateTime             infoTime    infoDate  total  \
# 0  2025-04-22 09:28:52  2025-04-22 09:25:14  2025-04-22     28
# 1  2025-04-22 09:28:52  2025-04-22 09:11:14  2025-04-22     21
# 2  2025-04-22 09:28:52  2025-04-22 08:50:02  2025-04-22     28
# 3  2025-04-22 09:28:52  2025-04-22 09:27:15  2025-04-22     11
# 4  2025-04-22 09:28:52  2025-04-22 08:50:02  2025-04-22     16
#
#    available_rent_bikes  latitude  longitude  available_return_bikes
# 0                     1  25.02605  121.54360                      27
# 1                     0  25.02565  121.54357                      21
# 2                     7  25.02429  121.54124                      21
# 3                     0  25.02351  121.54282                      11
# 4                    10  25.02153  121.54299                       5
