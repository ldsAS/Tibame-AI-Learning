# %% [markdown]
# <a href="https://colab.research.google.com/github/ldsAS/Tibame-AI-Learning/blob/main/Tibame20250428%E7%88%AC%E5%90%B9%E9%A2%A8%E6%A9%9F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import urllib.request as req
import bs4 as bs
import pandas as pd

# pandas
table = []

dn = "pchome/"
if not os.path.exists(dn):
    os.makedirs(dn)

url = "https://24h.pchome.com.tw/search/?q=%E5%90%B9%E9%A2%A8%E6%A9%9F"
resp = req.urlopen(url)
html = bs.BeautifulSoup(resp.read())
links = html.find_all("a", {"class":"c-prodInfoV2__link"})
for link in links:
    link_href = "https://24h.pchome.com.tw" + link["href"]
    print(link_href)
    # enter
    p_resp = req.urlopen(link_href)
    p_html = bs.BeautifulSoup(p_resp.read())
    # 產品品牌
    p_brand = p_html.find("span", {"class":"o-prodMainName__colorSecondary"})
    p_brand_text = p_brand.text.strip()
    # 產品名稱
    p_name = p_html.find("h1", {"class":"o-prodMainName__grayDarkest"})
    p_name_text = p_name.text.strip()
    # 滿額贈
    p_labels = p_html.find_all("div",{"class":"c-label_rectangle"})
    p_full_prize = "N"
    for p_label in p_labels:
        if "滿額贈" in p_label.text:
            p_full_prize = "Y"
            break
    # 評分
    p_rating_all = p_html.find("div", {"class":"c-ratingIcon__flex"})
    if not p_rating_all == None:
        p_rating = p_rating_all.find("div", {"class":"c-ratingIcon__textNumber"})
        p_rating_count = p_rating_all.find("a")
        p_rating_text = p_rating.text.strip()
        p_rating_count_text = p_rating_count.text.strip().replace("則評價", "")
    else:
        p_rating_text = "-"
        p_rating_count_text = "-"
    # 原價/價格
    p_pricebox = p_html.find("div", {"class":"o-prodPrice__priceBox"})
    p_price_now = p_pricebox.find("div", {"class":"o-prodPrice__price"})
    p_price_now_text = p_price_now.text.strip()
    p_price_origin = p_pricebox.find("div", {"class":"o-prodPrice__originalPrice"})
    if p_price_origin == None:
        p_price_origin_text = "-"
    else:
        p_price_origin_text = p_price_origin.text.strip()
    # 介紹
    p_intro_list = p_html.find_all("li", {"class":"c-blockCombine__item--prodSlogan"})
    p_intro_text_list = []
    for p_intro in p_intro_list:
        p_intro_text = p_intro.text.strip()
        p_intro_text_list.append(p_intro_text)
    p_intro_text_join = ""
    for p_intro_text in p_intro_text_list:
        p_intro_text_join = p_intro_text_join + "- " + p_intro_text + "\n"
    # 大圖片
    p_img = p_html.find("div", {"class":"c-radiusPhotoImage__img"}).find("img")
    p_img_src = p_img["src"]
    if not "https:" in p_img_src:
        p_img_src = "https:" + p_img_src
    # 幫你存
    fn = link_href.split("/")[-1]
    fn = dn + fn + ".jpg"
    req.urlretrieve(p_img_src, fn)

    # print("原價", p_price_origin_text)
    # print("目前售價", p_price_now_text)
    # print("評分:", p_rating_text)
    # print("幾則:", p_rating_count_text)
    # print("品牌:", p_brand_text)
    # print("商品:", p_name_text)
    # print("滿額贈:", p_full_prize)
    # print("介紹:", p_intro_text_join)
    # print("圖片位址:", p_img_src)
    data = {
        "原價":p_price_origin_text,
        "現價":p_price_now_text,
        "評分":p_rating_text,
        "評價個數":p_rating_count_text,
        "品牌":p_brand_text,
        "名稱":p_name_text,
        "滿額贈":p_full_prize,
        "介紹":p_intro_text_join,
        "圖片網址":p_img_src,
        "圖片儲存":fn,
    }
    table.append(data)
df = pd.DataFrame(table)
df.to_csv("pchome.csv", encoding="utf-8")
df
# Out:
# https://24h.pchome.com.tw/prod/DMAH47-A900I9MK8
# https://24h.pchome.com.tw/prod/DDBH8B-A900GK0TK
# https://24h.pchome.com.tw/prod/DMAHE2-1900IAF6I
# https://24h.pchome.com.tw/prod/DDDU04-A900HHN7T
# https://24h.pchome.com.tw/prod/DDBXFA-1900IFCES
# https://24h.pchome.com.tw/prod/DMAHBY-A900I0K1F
# https://24h.pchome.com.tw/prod/DMAHCW-A900IGQBP
# https://24h.pchome.com.tw/prod/DMAH4C-A900I7YVV
# https://24h.pchome.com.tw/prod/DMAH7C-A900HQBQH
# https://24h.pchome.com.tw/prod/DMAH4C-A900I7YVH
# https://24h.pchome.com.tw/prod/DMAH4C-A900HTGKT
# https://24h.pchome.com.tw/prod/DMAH02-A900FUEMV
# https://24h.pchome.com.tw/prod/DMAH02-A900AN6LF
# https://24h.pchome.com.tw/prod/DMAH02-A900ARLYE
# https://24h.pchome.com.tw/prod/DMAH7S-A90092JRB
# https://24h.pchome.com.tw/prod/DMAH02-A900GN0FB
# https://24h.pchome.com.tw/prod/DMAH7S-A900GDOA8
# https://24h.pchome.com.tw/prod/DYAN6U-A900GGFEZ
# https://24h.pchome.com.tw/prod/DMAH4E-A9007XOV1
# https://24h.pchome.com.tw/prod/DMAH02-A900GAYQW
# https://24h.pchome.com.tw/prod/DMAH02-A900AN6LL
# https://24h.pchome.com.tw/prod/DMAH4C-A900I98XQ
# https://24h.pchome.com.tw/prod/DMAH7M-A900I8F9D
# https://24h.pchome.com.tw/prod/DYANA0-A900GGFEJ
# https://24h.pchome.com.tw/prod/DMAH7S-A900H6W65
# https://24h.pchome.com.tw/prod/DMAH7S-A900GG1U7
# https://24h.pchome.com.tw/prod/DMAH7S-A900GG1W8
# https://24h.pchome.com.tw/prod/DMAH6Y-A900HCNN5
# https://24h.pchome.com.tw/prod/DMAH02-A900AN6R8
# https://24h.pchome.com.tw/prod/DMAH0O-A900FEXWL
# https://24h.pchome.com.tw/prod/DMAH02-A900GT9TF
# https://24h.pchome.com.tw/prod/DMBL3E-A900GYM4G
# https://24h.pchome.com.tw/prod/DMAH7S-A9009PI7V
# https://24h.pchome.com.tw/prod/DMAC01-A900C8WD6
# https://24h.pchome.com.tw/prod/QBAP0A-A9006MR6P
# https://24h.pchome.com.tw/prod/DMAHBK-A900F5VGG
# https://24h.pchome.com.tw/prod/DMBM0O-A900FML9R
# https://24h.pchome.com.tw/prod/DMAH15-A900HZAR0
# https://24h.pchome.com.tw/prod/DMAH02-A69900062
# https://24h.pchome.com.tw/prod/DMAHCQ-A900H8TIW
# https://24h.pchome.com.tw/prod/DMAHCQ-A900HMMTV
# https://24h.pchome.com.tw/prod/DMAHCQ-A900H8UN6
# https://24h.pchome.com.tw/prod/DMAH02-A90083MK3
# https://24h.pchome.com.tw/prod/DMAC01-A900EZHN2
# https://24h.pchome.com.tw/prod/DMAH02-A69891737
#          原價      現價   評分 評價個數               品牌  \
# 0    $6,280  $5,680    -    -            sOlac
# 1         -  $1,900  5.0    8            AVEDA
# 2         -  $1,290    -    -      acerpure 宏碁
# 3         -  $5,400  4.5    2            AVEDA
# 4    $2,550  $2,550    -    -            AVEDA
# 5    $1,295  $1,295  4.9   80        Xiaomi 小米
# 6    $4,480  $2,780  5.0    4            KINYO
# 7    $2,990  $2,799  4.9   53    Panasonic 國際牌
# 8    $2,900  $1,690  4.9   87           TESCOM
# 9    $2,990  $2,799  5.0   27    Panasonic 國際牌
# 10   $6,290  $5,288  5.0   67    Panasonic 國際牌
# 11        -  $7,990  4.9  148    Panasonic 國際牌
# 12   $2,190  $1,688  4.9  301    Panasonic 國際牌
# 13   $3,990  $2,480  5.0   72    Panasonic 國際牌
# 14     $790    $459  4.9  185           TESCOM
# 15  $13,900  $7,990  5.0   40    Panasonic 國際牌
# 16   $1,990    $999  4.9   20           TESCOM
# 17     $795    $595  5.0  217        Xiaomi 小米
# 18   $1,190    $649  4.9  170           TESCOM
# 19        -  $2,170  5.0   58    Panasonic 國際牌
# 20   $2,190  $1,688  4.9  215    Panasonic 國際牌
# 21   $6,290  $5,290  4.9   28    Panasonic 國際牌
# 22   $2,990  $2,799  5.0    3    Panasonic 國際牌
# 23   $1,395  $1,095  5.0  235        Xiaomi 小米
# 24     $990    $499  4.9   82           TESCOM
# 25   $2,490  $1,049  4.9  117           TESCOM
# 26     $990    $869  4.9   39           TESCOM
# 27     $980    $899  4.8   22    Panasonic 國際牌
# 28   $1,890  $1,590  5.0   61    Panasonic 國際牌
# 29     $690    $550  5.0   10              達新牌
# 30   $1,200    $799  4.6   59    Panasonic 國際牌
# 31   $6,980  $3,680  4.8   94      Dreame 追覓科技
# 32   $5,990  $3,591  4.6    8  Nobby by TESCOM
# 33        -  $1,488  4.7   55      PHILIPS 飛利浦
# 34   $2,590  $1,670  4.3    3    Panasonic 國際牌
# 35   $5,280  $3,980  4.9   40            sOlac
# 36     $990    $869  5.0    4           TESCOM
# 37   $5,880  $2,680  5.0    5    SIMPLITE 簡輕家居
# 38     $999    $788  5.0   13    Panasonic 國際牌
# 39  $14,600  $1,890  5.0    4           MIDORI
# 40  $14,600  $2,199  5.0    2           MIDORI
# 41  $14,600  $1,890  5.0   12           MIDORI
# 42   $2,090  $1,399  4.9    8    Panasonic 國際牌
# 43   $3,990  $2,688  5.0    3      PHILIPS 飛利浦
# 44     $888    $599  4.8   18    Panasonic 國際牌
#
#                                                    名稱 滿額贈  \
# 0                 So-Wrap 7 in 1 多功能專業造型吹風機(SR-1000G)   N
# 1                       蘊活淨瑕頭皮調理液 100ml (鎮靜紓緩頭皮並祛除頭氣)   N
# 2                  Acerpure beauty 雙效負離子吹風機 HD364-10W   N
# 3                                      蘊活煥欣洗髮精 1000ml   N
# 4                                             蘊活純香養護組   N
# 5                                            負離子高速吹風機   N
# 6                                   全球電壓無刷吹風機 KH-9660   N
# 7                             高速馬達吹風機 EH-NE6M-C 焦糖奶茶色   N
# 8                                專業負離子吹風機 TD760TW 雲朵白   N
# 9                             高速馬達吹風機 EH-NE6M-A 寶寶粉藍色   N
# 10                                 奈米水離子吹風機 EH-NA9N-H   N
# 11                                 高滲透奈米水離子吹風機EH-NA0J   N
# 12                                奈米水離子吹風機(EH-NA27-W)   N
# 13                               奈米水離子吹風機(EH-NA55-PN)   N
# 14                                    大風量負離子吹風機TID292   N
# 15                         高滲透奈米水離子吹風機 EH-NA0J-A(霧墨藍)   N
# 16                                   輕巧大風量吹風機TD550ATW   N
# 17                                        負離子吹風機 H300   N
# 18                               大風量負離子吹風機TID450(玫瑰桃)   N
# 19                              奈米水離子吹風機EH-NA32-T-雲灰紫   N
# 20                                           奈米水離子吹風機   N
# 21                                 奈米水離子吹風機 EH-NA9N-H   N
# 22                                   負離子溫控吹風機 EH-NE6M   N
# 23                                        水離子吹風機 H500   N
# 24                                遠紅外線負離子吹風機 TID456TW   N
# 25                            防靜電大風量吹風機TID2200TW(珍珠白)   N
# 26                               專業型大風量負離子吹風機TID960TW   N
# 27                        1400W負離子吹風機 EH-NE21 大風力 公司貨   N
# 28                                   雙負離子吹風機EH-NE74-N   N
# 29              國際電壓 陶瓷折疊式吹風機 雙壓 1400W 旅行首選 黑色 FD-170   N
# 30                             雙負離子吹風機 EH-NE43-T(雲灰紫)   N
# 31                                  Glory三億鉑金負離子高速吹風機   N
# 32             日本沙龍級專業品牌 日本專業沙龍修護離子吹風機 NIB3000TW(晨霧白)   N
# 33                         沙龍級護髮負離子吹風機-霧藍黑(BHD518/01)   N
# 34                            奈米水離子三段溫控折疊式吹風機 EH-NA27   N
# 35  SD 1000 專業負離子吹風機 無刷馬達 T型吹風機 網美力薦吹風機 網路熱銷爆款吹風機 ...   N
# 36                                    TID960TW 負離子吹風機   N
# 37                                              高速吹風機   N
# 38                                負離子速乾型冷熱吹風機 EH-NE11   N
# 39                         【美多莉】高風速溫控負離子吹風機加輕巧收納袋-紫金色   N
# 40          【美多莉】Hypersonic 國際全電壓 高速負離子吹風機-櫻花粉(輕巧收納組)   N
# 41                        【美多莉】高風速溫控負離子吹風機 加輕巧收納袋-藍金色   N
# 42                                負離子吹風機 EH-NE73-P(粉)   N
# 43                     智能護髮礦物負離子吹風機-玫瑰粉霧( BHD538/01 )   N
# 44                                   速乾型冷熱吹風機 EH-ND21   N
#
#                                                    介紹  \
# 0        - 12種吹整模式 不挑髮質\n- 滑動解鎖一鍵變身捲髮棒\n- 自動清潔 雙向吹送\n
# 1     - 48小時清爽控油，呵護髮肌\n- 免沖洗直接噴於頭皮並搭配按摩\n- 可於日間隨時使用\n
# 2   - ProDry多風道氣流雙效吹嘴\n- 2,200萬高濃度負離子\n- 便利收納 沙龍級享...
# 3   - 去除頭皮老廢角質與殘留物堆積\n- 天然起泡成分，溫和清潔\n- 細軟髮或落髮問題特別推薦\n
# 4     - 蘊活系列呵護髮肌，秀髮豐盈新生\n- 純香清新經典花香\n- 細軟髮或落髮問題特別推薦\n
# 5   - 高濃度負離子 | 中和靜電，減少毛躁\n- 400g輕巧機身 | 長時間使用也不疲累\n...
# 6   - 100-240V全球電壓自動切換，隨插即吹，使用地區不受限\n- 90度折疊機身設計，節...
# 7   - 直線風梳技術 水平出風口吹出直線風流,使頭髮 不易打結,更滑順。\n- BLDC高速馬達...
# 8   - 日本「減法美學」羽量級BLDC 吹風機\n- 高濃度負離子釋放 締造水潤光澤秀髮\n- ...
# 9   - 直線風梳技術 水平出風口吹出直線風流,使頭髮 不易打結,更滑順。\n- BLDC高速馬達...
# 10  - 多重護髮潤肌模式\n- 搭載奈米水離子 & 礦物負離子\n- 搭載雙重智能溫度感測器,舒...
# 11  - 獨家高滲透奈米水離子保濕科技，水分提升1.9倍。\n- 礦物負離子強韌秀髮\n- 智慧溫...
# 12          - 奈米水離子潤澤滲透護髮科技\n- 加頭髮的保濕度\n- 頭皮到髮尾完整保養\n
# 13     - 國際電壓，海外國內兩用\n- 小巧機身，折疊好攜帶\n- 奈米負離子1000倍保濕力\n
# 14  - 速乾！大風量1.4Ｍ³/分\n- 使用負離子, 成為水潤的髮尾\n- 從乾燥修護頭髮 保...
# 15                 - 高滲透奈米水離子\n- 礦物負離子\n- 2個智能溫度感應器\n
# 16  - 黃金三角式​負離子釋放技術，讓秀髮水潤柔亮\n- 三段風溫Ｘ三段風量共9種模式\n- 粉...
# 17    - 9.5 公分超短外殼\n- 20 公尺 / 秒 超大氣流\n- 5,000 萬個負離子\n
# 18  - 優雅輕量475g  雙倍負離子\n- 大風量速乾  三檔風速\n- 可折疊手把 防過熱裝置\n
# 19             - 附速乾吹嘴、造型吹嘴\n- 靜電抑制機能\n- 可折疊機身，方便收納\n
# 20     - 奈米水離子潤澤滲透護髮科技\n- 1400W大風量設計\n- 三段溫度/二段風量設計\n
# 21  - 多重護髮潤肌模式\n- 搭載奈米水離子 & 礦物負離子\n- 搭載雙重智能溫度感測器,舒...
# 22  - BLDC高速馬達/強大風流/快速吹乾頭髮\n- 4段風溫模式/2段風速/自由選擇\n- ...
# 23                  - 雙重水離子護髮\n- 20m/s*超高風速\n- 金屬機身\n
# 24  - 速乾! 沙龍級風量1.6Ｍ³/分\n- 遠紅外線快速導熱不傷髮\n- 雙重負離子釋放滋潤...
# 25         - 速乾大風量２.０M³/分\n- 高效率 １５００Ｗ\n- 抑制靜電 修護離子\n
# 26   - 4個負離子釋放點\n- 9種風量模式，冷風定型\n- 雙氣流吹嘴，速乾與吹整模式兩種選擇\n
# 27  - 保濕負離子-吹頭髮同時為秀髮保濕\n- 1400W.大風量-快速吹乾好省時\n- 兩段風速\n
# 28            - 外置雙負離子設計\n- 風量選擇：三段式\n- 溫度：冷/暖/熱風三種\n
# 29             - 陶瓷遠紅外線\n- 可折疊好收納\n- 雙電壓設計110V/220V\n
# 30           - 1200W大馬力\n- 3段式風溫與風量調整\n- 外置雙負離子吹口設計\n
# 31  - 3億鉑金負離子，護髮撫平毛躁\n- 57度恆溫呵護，冷熱循環減少秀髮損傷\n- 輕巧機身...
# 32   - 三段溫度&三段風速調節\n- 修護離子有效抑制靜電\n- 附專用立架，吹整長髮輕鬆不費力\n
# 33          - *1500W 強力瓦數，大出風\n- *高效負離子護髮\n- *可摺疊收納\n
# 34  - 小型輕量化設計\n- Nanoe奈米水離子 潤澤滲透護髮科技\n- 三段溫度/二段風量設計\n
# 35                - 智慧恆溫設計\n- 動力氣體流道設計\n- 4種溫度12種模式\n
# 36  - 超保濕負離子保濕秀髮\n- 可折疊易收納攜帶方便\n- 雙氣流吹嘴 速乾與吹整模式兩種選擇\n
# 37  - 2檔風速、3檔風溫隨意切換，3色LED溫度顯示(冷/暖/熱)，冷熱、強勁/柔和交替智慧模...
# 38  - 速乾護髮吹嘴，瞬間乾燥不傷秀髮\n- 外置負離子設計，在頭髮表面形成保護層，有效鎖住秀髮...
# 39  - 6段溫控×5段風速，變化30種整髮造型\n- 110000rpm，Hypersonic數...
# 40  - 全球電壓100V-240V自動調適\n- 首創6段溫控×5段風速\n- 2億高科技負離子...
# 41  - 6段溫控×5段風速，變化30種整髮造型\n- 110000rpm，Hypersonic數...
# 42           - 溫冷雙風出風口設計\n- 雙負離子\n- 三段溫度選擇/二段速冷定型開關\n
# 43  - 4,000萬保濕鎖水負離子\n- ThermoShield防熱吹護技術\n- 防曬礦物鋅...
# 44  - 速乾護髮吹嘴，瞬間乾燥不傷秀髮\n- 強/弱兩種風壓，完美吹乾頭髮\n- 風量均勻分佈到...
#
#                                                  圖片網址  \
# 0   https://img.pchome.com.tw/cs/items/DMAH47A900I...
# 1   https://img.pchome.com.tw/cs/items/DDBH8BA900G...
# 2   https://img.pchome.com.tw/cs/items/DMAHE21900I...
# 3   https://img.pchome.com.tw/cs/items/DDDU04A900H...
# 4   https://img.pchome.com.tw/cs/items/DDBXFA1900I...
# 5   https://img.pchome.com.tw/cs/items/DMAHBYA900I...
# 6   https://cs-a.ecimg.tw/items/DMAHCWA900IGQBP/yt...
# 7   https://img.pchome.com.tw/cs/items/DMAH4CA900I...
# 8   https://img.pchome.com.tw/cs/items/DMAH7CA900H...
# 9   https://img.pchome.com.tw/cs/items/DMAH4CA900I...
# 10  https://img.pchome.com.tw/cs/items/DMAH4CA900H...
# 11  https://cs-a.ecimg.tw/items/DMAH02A900FUEMV/yt...
# 12  https://img.pchome.com.tw/cs/items/DMAH02A900A...
# 13  https://img.pchome.com.tw/cs/items/DMAH02A900A...
# 14  https://img.pchome.com.tw/cs/items/DMAH7SA9009...
# 15  https://img.pchome.com.tw/cs/items/DMAH02A900G...
# 16  https://img.pchome.com.tw/cs/items/DMAH7SA900G...
# 17  https://img.pchome.com.tw/cs/items/DYAN6UA900G...
# 18  https://img.pchome.com.tw/cs/items/DMAH4EA9007...
# 19  https://img.pchome.com.tw/cs/items/DMAH02A900G...
# 20  https://img.pchome.com.tw/cs/items/DMAH02A900A...
# 21  https://img.pchome.com.tw/cs/items/DMAH4CA900I...
# 22  https://img.pchome.com.tw/cs/items/DMAH7MA900I...
# 23  https://img.pchome.com.tw/cs/items/DYANA0A900G...
# 24  https://img.pchome.com.tw/cs/items/DMAH7SA900H...
# 25  https://img.pchome.com.tw/cs/items/DMAH7SA900G...
# 26  https://img.pchome.com.tw/cs/items/DMAH7SA900G...
# 27  https://img.pchome.com.tw/cs/items/DMAH6YA900H...
# 28  https://img.pchome.com.tw/cs/items/DMAH02A900A...
# 29  https://img.pchome.com.tw/cs/items/DMAH0OA900F...
# 30  https://img.pchome.com.tw/cs/items/DMAH02A900G...
# 31  https://cs-a.ecimg.tw/items/DMBL3EA900GYM4G/yt...
# 32  https://img.pchome.com.tw/cs/items/DMAH7SA9009...
# 33  https://img.pchome.com.tw/cs/items/DMAC01A900C...
# 34  https://img.pchome.com.tw/cs/items/QBAP0AA9006...
# 35  https://img.pchome.com.tw/cs/items/DMAHBKA900F...
# 36  https://img.pchome.com.tw/cs/items/DMBM0OA900F...
# 37  https://img.pchome.com.tw/cs/items/DMAH15A900H...
# 38  https://img.pchome.com.tw/cs/items/DMAH02A6990...
# 39  https://img.pchome.com.tw/cs/items/DMAHCQA900H...
# 40  https://cs-a.ecimg.tw/items/DMAHCQA900HMMTV/yt...
# 41  https://img.pchome.com.tw/cs/items/DMAHCQA900H...
# 42  https://img.pchome.com.tw/cs/items/DMAH02A9008...
# 43  https://img.pchome.com.tw/cs/items/DMAC01A900E...
# 44  https://img.pchome.com.tw/cs/items/DMAH02A6989...
#
#                            圖片儲存
# 0   pchome/DMAH47-A900I9MK8.jpg
# 1   pchome/DDBH8B-A900GK0TK.jpg
# 2   pchome/DMAHE2-1900IAF6I.jpg
# 3   pchome/DDDU04-A900HHN7T.jpg
# 4   pchome/DDBXFA-1900IFCES.jpg
# 5   pchome/DMAHBY-A900I0K1F.jpg
# 6   pchome/DMAHCW-A900IGQBP.jpg
# 7   pchome/DMAH4C-A900I7YVV.jpg
# 8   pchome/DMAH7C-A900HQBQH.jpg
# 9   pchome/DMAH4C-A900I7YVH.jpg
# 10  pchome/DMAH4C-A900HTGKT.jpg
# 11  pchome/DMAH02-A900FUEMV.jpg
# 12  pchome/DMAH02-A900AN6LF.jpg
# 13  pchome/DMAH02-A900ARLYE.jpg
# 14  pchome/DMAH7S-A90092JRB.jpg
# 15  pchome/DMAH02-A900GN0FB.jpg
# 16  pchome/DMAH7S-A900GDOA8.jpg
# 17  pchome/DYAN6U-A900GGFEZ.jpg
# 18  pchome/DMAH4E-A9007XOV1.jpg
# 19  pchome/DMAH02-A900GAYQW.jpg
# 20  pchome/DMAH02-A900AN6LL.jpg
# 21  pchome/DMAH4C-A900I98XQ.jpg
# 22  pchome/DMAH7M-A900I8F9D.jpg
# 23  pchome/DYANA0-A900GGFEJ.jpg
# 24  pchome/DMAH7S-A900H6W65.jpg
# 25  pchome/DMAH7S-A900GG1U7.jpg
# 26  pchome/DMAH7S-A900GG1W8.jpg
# 27  pchome/DMAH6Y-A900HCNN5.jpg
# 28  pchome/DMAH02-A900AN6R8.jpg
# 29  pchome/DMAH0O-A900FEXWL.jpg
# 30  pchome/DMAH02-A900GT9TF.jpg
# 31  pchome/DMBL3E-A900GYM4G.jpg
# 32  pchome/DMAH7S-A9009PI7V.jpg
# 33  pchome/DMAC01-A900C8WD6.jpg
# 34  pchome/QBAP0A-A9006MR6P.jpg
# 35  pchome/DMAHBK-A900F5VGG.jpg
# 36  pchome/DMBM0O-A900FML9R.jpg
# 37  pchome/DMAH15-A900HZAR0.jpg
# 38  pchome/DMAH02-A69900062.jpg
# 39  pchome/DMAHCQ-A900H8TIW.jpg
# 40  pchome/DMAHCQ-A900HMMTV.jpg
# 41  pchome/DMAHCQ-A900H8UN6.jpg
# 42  pchome/DMAH02-A90083MK3.jpg
# 43  pchome/DMAC01-A900EZHN2.jpg
# 44  pchome/DMAH02-A69891737.jpg

# %%
# 名字
# 原價/目前售價
# 滿額贈是否有(Y/N)
# 進去以後
# 評價/幾則
# 介紹
# 圖片的網址
