# %% [markdown]
# <a href="https://colab.research.google.com/github/ldsAS/Tibame-AI-Learning/blob/main/Tibame20250428%E7%88%AC%E5%90%B9%E9%A2%A8%E6%A9%9F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request as req
import bs4 as bs
url = "https://24h.pchome.com.tw/search/?q=%E5%90%B9%E9%A2%A8%E6%A9%9F"
resp = req.urlopen(url)
html = bs.BeautifulSoup(resp.read())
links = html.find_all("a", {"class":"c-prodInfoV2__link"})
for link in links:
    link_href = "https://24h.pchome.com.tw" + link["href"]
    print(link_href)
    # enter
    p_resp = req.urlopen(link_href)
    p_html = bs.BeautifulSoup(p_resp.read())
    # 產品品牌
    p_brand = p_html.find("span", {"class":"o-prodMainName__colorSecondary"})
    p_brand_text = p_brand.text.strip()
    # 產品名稱
    p_name = p_html.find("h1", {"class":"o-prodMainName__grayDarkest"})
    p_name_text = p_name.text.strip()
    # 滿額贈
    p_labels = p_html.find_all("div",{"class":"c-label_rectangle"})
    p_full_prize = "N"
    for p_label in p_labels:
        if "滿額贈" in p_label.text:
            p_full_prize = "Y"
            break
    # 評分
    p_rating = p_html.find("div", {"class":"c-ratingIcon__textNumber"})
    if p_rating == None:
        p_rating_text = "-"
    else:
        p_rating_text = p_rating.text.strip()

    print(p_rating_text)
    print(p_brand_text)
    print(p_name_text)
    print("滿額贈:", p_full_prize)
# Out:
# https://24h.pchome.com.tw/prod/DMAH47-A900I26G1
# 5.0
# sOlac
# SD-1000Pro 白金色 國際電壓專業負離子吹風機 自動變壓 無刷馬達 T型吹風機 輕巧輕量吹風機
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DDBXOU-A900ICDTX
# 4.0
# AVEDA
# 蘊活煥欣豐盈菁華 150ml*2 (適用稀疏髮/幫助髮絲健康生長)
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAHE2-1900IAF6I
# -
# acerpure 宏碁
# Acerpure beauty 雙效負離子吹風機 HD364-10W
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DDDU04-A900HHN7T
# 4.5
# AVEDA
# 蘊活煥欣洗髮精 1000ml
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DDBXFA-1900IFCES
# -
# AVEDA
# 蘊活純香養護組
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAHBY-A900I0K1F
# 4.9
# Xiaomi 小米
# 負離子高速吹風機
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAHCW-A900IGQBP
# 5.0
# KINYO
# 全球電壓無刷吹風機 KH-9660
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH4C-A900I7YVV
# 4.9
# Panasonic 國際牌
# 高速馬達吹風機 EH-NE6M-C 焦糖奶茶色
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH7C-A900HQBQH
# 4.9
# TESCOM
# 專業負離子吹風機 TD760TW 雲朵白
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH4C-A900I7YVH
# 5.0
# Panasonic 國際牌
# 高速馬達吹風機 EH-NE6M-A 寶寶粉藍色
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH02-A900AN6LF
# 4.9
# Panasonic 國際牌
# 奈米水離子吹風機(EH-NA27-W)
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH02-A900ARLYE
# 5.0
# Panasonic 國際牌
# 奈米水離子吹風機(EH-NA55-PN)
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH4C-A900HTGKT
# 5.0
# Panasonic 國際牌
# 奈米水離子吹風機 EH-NA9N-H
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH02-A900FUEMV
# 4.9
# Panasonic 國際牌
# 高滲透奈米水離子吹風機EH-NA0J
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH7S-A90092JRB
# 4.9
# TESCOM
# 大風量負離子吹風機TID292
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH02-A900GN0FB
# 5.0
# Panasonic 國際牌
# 高滲透奈米水離子吹風機 EH-NA0J-A(霧墨藍)
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH7S-A900GDOA8
# 4.9
# TESCOM
# 輕巧大風量吹風機TD550ATW
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH4E-A9007XOV1
# 4.9
# TESCOM
# 大風量負離子吹風機TID450(玫瑰桃)
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DYAN6U-A900GGFEZ
# 5.0
# Xiaomi 小米
# 負離子吹風機 H300
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH02-A900GAYQW
# 5.0
# Panasonic 國際牌
# 奈米水離子吹風機EH-NA32-T-雲灰紫
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH02-A900AN6LL
# 4.9
# Panasonic 國際牌
# 奈米水離子吹風機
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH4C-A900I98XQ
# 4.9
# Panasonic 國際牌
# 奈米水離子吹風機 EH-NA9N-H
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH7M-A900I8F9D
# 5.0
# Panasonic 國際牌
# 負離子溫控吹風機 EH-NE6M
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DYANA0-A900GGFEJ
# 5.0
# Xiaomi 小米
# 水離子吹風機 H500
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH7S-A900H6W65
# 4.9
# TESCOM
# 遠紅外線負離子吹風機 TID456TW
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH7S-A900GG1U7
# 4.9
# TESCOM
# 防靜電大風量吹風機TID2200TW(珍珠白)
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH7S-A900GG1W8
# 4.9
# TESCOM
# 專業型大風量負離子吹風機TID960TW
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH6Y-A900HCNN5
# 4.8
# Panasonic 國際牌
# 1400W負離子吹風機 EH-NE21 大風力 公司貨
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH02-A900AN6R8
# 5.0
# Panasonic 國際牌
# 雙負離子吹風機EH-NE74-N
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH0O-A900FEXWL
# 5.0
# 達新牌
# 國際電壓 陶瓷折疊式吹風機 雙壓 1400W 旅行首選 黑色 FD-170
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH7S-A9009PI7V
# 4.6
# Nobby by TESCOM
# 日本沙龍級專業品牌 日本專業沙龍修護離子吹風機 NIB3000TW(晨霧白)
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAC01-A900C8WD6
# 4.7
# PHILIPS 飛利浦
# 沙龍級護髮負離子吹風機-霧藍黑(BHD518/01)
# 滿額贈: N
# https://24h.pchome.com.tw/prod/QBAP0A-A9006MR6P
# 4.3
# Panasonic 國際牌
# 奈米水離子三段溫控折疊式吹風機 EH-NA27
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH02-A900GT9TF
# 4.6
# Panasonic 國際牌
# 雙負離子吹風機 EH-NE43-T(雲灰紫)
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAHBK-A900F5VGG
# 4.9
# sOlac
# SD 1000 專業負離子吹風機 無刷馬達 T型吹風機 網美力薦吹風機 網路熱銷爆款吹風機 輕量吹風機
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMBL3E-A900GYM4G
# 4.8
# Dreame 追覓科技
# Glory三億鉑金負離子高速吹風機
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMBM0O-A900FML9R
# 5.0
# TESCOM
# TID960TW 負離子吹風機
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH15-A900HZAR0
# 5.0
# SIMPLITE 簡輕家居
# 高速吹風機
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH02-A69900062
# 5.0
# Panasonic 國際牌
# 負離子速乾型冷熱吹風機 EH-NE11
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAHCQ-A900H8TIW
# 5.0
# MIDORI
# 【美多莉】高風速溫控負離子吹風機加輕巧收納袋-紫金色
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAHCQ-A900HMMTV
# 5.0
# MIDORI
# 【美多莉】Hypersonic 國際全電壓 高速負離子吹風機-櫻花粉(輕巧收納組)
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAHCQ-A900H8UN6
# 5.0
# MIDORI
# 【美多莉】高風速溫控負離子吹風機 加輕巧收納袋-藍金色
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH02-A69891737
# 4.8
# Panasonic 國際牌
# 速乾型冷熱吹風機 EH-ND21
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH4E-A9007GS5Z
# 4.8
# TESCOM
# 白金奈米膠原蛋白吹風機 TCD5000TW
# 滿額贈: N
# https://24h.pchome.com.tw/prod/DMAH02-A90083MK3
# 4.9
# Panasonic 國際牌
# 負離子吹風機 EH-NE73-P(粉)
# 滿額贈: N

# %%
# 名字
# 原價/目前售價
# 滿額贈是否有(Y/N)
# 進去以後
# 評價/幾則
# 介紹
# 圖片的網址
